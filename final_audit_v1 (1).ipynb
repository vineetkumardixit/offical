# %%
import pandas as pd
import os

def merge_department_responses(original_file, response_files, output_file):
    print(f"Loading original file: {original_file}")
    try:
        xl_original = pd.ExcelFile(original_file)
    except Exception as e:
        print(f"Error loading original file: {e}")
        return
    
    merged_sheets = {}
    
    for sheet in xl_original.sheet_names:
        print(f"Processing sheet: {sheet}")
        try:
            df_original = xl_original.parse(sheet)
        except Exception as e:
            print(f"Error reading sheet '{sheet}' from original file: {e}")
            continue
        
        print(f"Original sheet '{sheet}' loaded with {df_original.shape[0]} rows and {df_original.shape[1]} columns")
        
        for response_file in response_files:
            print(f"Checking response file: {response_file}")
            try:
                xl_response = pd.ExcelFile(response_file)
            except Exception as e:
                print(f"Error loading response file '{response_file}': {e}")
                continue
            
            if sheet in xl_response.sheet_names:
                print(f"Merging data from {response_file} for sheet: {sheet}")
                try:
                    df_response = xl_response.parse(sheet)
                    print(f"Response sheet '{sheet}' has {df_response.shape[0]} rows and {df_response.shape[1]} columns")
                    
                    new_columns = df_response.columns[len(df_original.columns):]
                    print(f"Identified new columns: {list(new_columns)}")
                    
                    df_original = df_original.merge(df_response[new_columns], left_index=True, right_index=True, how='left')
                    print(f"After merging, sheet '{sheet}' has {df_original.shape[0]} rows and {df_original.shape[1]} columns")
                except Exception as e:
                    print(f"Error merging sheet '{sheet}' from '{response_file}': {e}")
                    continue
        
        merged_sheets[sheet] = df_original
    
    print(f"Saving final merged file: {output_file}")
    try:
        with pd.ExcelWriter(output_file) as writer:
            for sheet, df in merged_sheets.items():
                df.to_excel(writer, sheet_name=sheet, index=False)
        print(f"Final merged Excel saved as {output_file}")
    except Exception as e:
        print(f"Error saving final merged file: {e}")

# Get user input for file paths
input_path = input("Enter the directory where Excel files are located: ").strip()
original_file_name = input("Enter the original Excel file name (including .xlsx): ").strip()
original_file = os.path.join(input_path, original_file_name)

# Ask user if all response files are in the same directory
auto_fetch = input("Should all response files be fetched automatically from this directory? (yes/no): ").strip().lower()
if auto_fetch == 'yes':
    response_files = [os.path.join(input_path, f) for f in os.listdir(input_path) if f.endswith(".xlsx") and f != original_file_name]
else:
    response_file_names = input("Enter the response Excel file names separated by commas: ").strip().split(',')
    response_files = [os.path.join(input_path, name.strip()) for name in response_file_names]

output_file = os.path.join(input_path, "final_merged.xlsx")

merge_department_responses(original_file, response_files, output_file)
# Out:
# Enter the directory where Excel files are located:  /Users/vineetdixit/Desktop/merge
# Enter the original Excel file name (including .xlsx):  Audit Report May24-Sept24.xlsx
# Should all response files be fetched automatically from this directory? (yes/no):  yes
# Loading original file: /Users/vineetdixit/Desktop/merge/Audit Report May24-Sept24.xlsx
# Processing sheet: Report
# Original sheet 'Report' loaded with 34 rows and 5 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 3.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 3.xlsx for sheet: Report
# Response sheet 'Report' has 34 rows and 5 columns
# Identified new columns: []
# After merging, sheet 'Report' has 34 rows and 5 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 2.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 2.xlsx for sheet: Report
# Response sheet 'Report' has 34 rows and 5 columns
# Identified new columns: []
# After merging, sheet 'Report' has 34 rows and 5 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/final_merged.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/final_merged.xlsx for sheet: Report
# Response sheet 'Report' has 34 rows and 5 columns
# Identified new columns: []
# After merging, sheet 'Report' has 34 rows and 5 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 5.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 5.xlsx for sheet: Report
# Response sheet 'Report' has 34 rows and 5 columns
# Identified new columns: []
# After merging, sheet 'Report' has 34 rows and 5 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 4.xlsx
# Checking response file: /Users/vineetdixit/Desktop/merge/~$final_merged.xlsx
# Error loading response file '/Users/vineetdixit/Desktop/merge/~$final_merged.xlsx': Excel file format cannot be determined, you must specify an engine manually.
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 1.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 1.xlsx for sheet: Report
# Response sheet 'Report' has 34 rows and 5 columns
# Identified new columns: []
# After merging, sheet 'Report' has 34 rows and 5 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/~$Audit Report May24-Sept24.xlsx
# Error loading response file '/Users/vineetdixit/Desktop/merge/~$Audit Report May24-Sept24.xlsx': Excel file format cannot be determined, you must specify an engine manually.
# Processing sheet: Score Card
# Original sheet 'Score Card' loaded with 43 rows and 48 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 3.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 3.xlsx for sheet: Score Card
# Response sheet 'Score Card' has 38 rows and 48 columns
# Identified new columns: []
# After merging, sheet 'Score Card' has 43 rows and 48 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 2.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 2.xlsx for sheet: Score Card
# Response sheet 'Score Card' has 38 rows and 48 columns
# Identified new columns: []
# After merging, sheet 'Score Card' has 43 rows and 48 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/final_merged.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/final_merged.xlsx for sheet: Score Card
# Response sheet 'Score Card' has 43 rows and 48 columns
# Identified new columns: []
# After merging, sheet 'Score Card' has 43 rows and 48 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 5.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 5.xlsx for sheet: Score Card
# Response sheet 'Score Card' has 38 rows and 48 columns
# Identified new columns: []
# After merging, sheet 'Score Card' has 43 rows and 48 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 4.xlsx
# Checking response file: /Users/vineetdixit/Desktop/merge/~$final_merged.xlsx
# Error loading response file '/Users/vineetdixit/Desktop/merge/~$final_merged.xlsx': Excel file format cannot be determined, you must specify an engine manually.
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 1.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 1.xlsx for sheet: Score Card
# Response sheet 'Score Card' has 38 rows and 48 columns
# Identified new columns: []
# After merging, sheet 'Score Card' has 43 rows and 48 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/~$Audit Report May24-Sept24.xlsx
# Error loading response file '/Users/vineetdixit/Desktop/merge/~$Audit Report May24-Sept24.xlsx': Excel file format cannot be determined, you must specify an engine manually.
# Processing sheet: 1
# Original sheet '1' loaded with 203 rows and 42 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 3.xlsx
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 2.xlsx
# Checking response file: /Users/vineetdixit/Desktop/merge/final_merged.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/final_merged.xlsx for sheet: 1
# Response sheet '1' has 203 rows and 42 columns
# Identified new columns: []
# After merging, sheet '1' has 203 rows and 42 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 5.xlsx
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 4.xlsx
# Checking response file: /Users/vineetdixit/Desktop/merge/~$final_merged.xlsx
# Error loading response file '/Users/vineetdixit/Desktop/merge/~$final_merged.xlsx': Excel file format cannot be determined, you must specify an engine manually.
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 1.xlsx
# Checking response file: /Users/vineetdixit/Desktop/merge/~$Audit Report May24-Sept24.xlsx
# Error loading response file '/Users/vineetdixit/Desktop/merge/~$Audit Report May24-Sept24.xlsx': Excel file format cannot be determined, you must specify an engine manually.
# Processing sheet: 2
# Original sheet '2' loaded with 48 rows and 47 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 3.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 3.xlsx for sheet: 2
# Response sheet '2' has 48 rows and 45 columns
# Identified new columns: []
# After merging, sheet '2' has 48 rows and 47 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 2.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 2.xlsx for sheet: 2
# Response sheet '2' has 48 rows and 45 columns
# Identified new columns: []
# After merging, sheet '2' has 48 rows and 47 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/final_merged.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/final_merged.xlsx for sheet: 2
# Response sheet '2' has 48 rows and 47 columns
# Identified new columns: []
# After merging, sheet '2' has 48 rows and 47 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 5.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 5.xlsx for sheet: 2
# Response sheet '2' has 48 rows and 45 columns
# Identified new columns: []
# After merging, sheet '2' has 48 rows and 47 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 4.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 4.xlsx for sheet: 2
# Response sheet '2' has 7 rows and 45 columns
# Identified new columns: []
# After merging, sheet '2' has 48 rows and 47 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/~$final_merged.xlsx
# Error loading response file '/Users/vineetdixit/Desktop/merge/~$final_merged.xlsx': Excel file format cannot be determined, you must specify an engine manually.
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 1.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 1.xlsx for sheet: 2
# Response sheet '2' has 48 rows and 45 columns
# Identified new columns: []
# After merging, sheet '2' has 48 rows and 47 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/~$Audit Report May24-Sept24.xlsx
# Error loading response file '/Users/vineetdixit/Desktop/merge/~$Audit Report May24-Sept24.xlsx': Excel file format cannot be determined, you must specify an engine manually.
# Processing sheet: 3
# Original sheet '3' loaded with 2280 rows and 42 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 3.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 3.xlsx for sheet: 3
# Response sheet '3' has 194 rows and 45 columns
# Identified new columns: ['Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44']
# After merging, sheet '3' has 2280 rows and 45 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 2.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 2.xlsx for sheet: 3
# Error merging sheet '3' from '/Users/vineetdixit/Desktop/merge/Final Audit Report 2.xlsx': Value must be either numerical or a string containing a wildcard
# Checking response file: /Users/vineetdixit/Desktop/merge/final_merged.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/final_merged.xlsx for sheet: 3
# Response sheet '3' has 2280 rows and 45 columns
# Identified new columns: []
# After merging, sheet '3' has 2280 rows and 45 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 5.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 5.xlsx for sheet: 3
# Response sheet '3' has 194 rows and 45 columns
# Identified new columns: []
# After merging, sheet '3' has 2280 rows and 45 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 4.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 4.xlsx for sheet: 3
# Response sheet '3' has 31 rows and 45 columns
# Identified new columns: []
# After merging, sheet '3' has 2280 rows and 45 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/~$final_merged.xlsx
# Error loading response file '/Users/vineetdixit/Desktop/merge/~$final_merged.xlsx': Excel file format cannot be determined, you must specify an engine manually.
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 1.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 1.xlsx for sheet: 3
# Response sheet '3' has 194 rows and 45 columns
# Identified new columns: []
# After merging, sheet '3' has 2280 rows and 45 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/~$Audit Report May24-Sept24.xlsx
# Error loading response file '/Users/vineetdixit/Desktop/merge/~$Audit Report May24-Sept24.xlsx': Excel file format cannot be determined, you must specify an engine manually.
# Processing sheet: 4
# Original sheet '4' loaded with 31 rows and 46 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 3.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 3.xlsx for sheet: 4
# Response sheet '4' has 31 rows and 50 columns
# Identified new columns: ['Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49']
# After merging, sheet '4' has 31 rows and 50 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 2.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 2.xlsx for sheet: 4
# Response sheet '4' has 31 rows and 50 columns
# Identified new columns: []
# After merging, sheet '4' has 31 rows and 50 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/final_merged.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/final_merged.xlsx for sheet: 4
# Response sheet '4' has 31 rows and 50 columns
# Identified new columns: []
# After merging, sheet '4' has 31 rows and 50 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 5.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 5.xlsx for sheet: 4
# Response sheet '4' has 31 rows and 50 columns
# Identified new columns: []
# After merging, sheet '4' has 31 rows and 50 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 4.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 4.xlsx for sheet: 4
# Response sheet '4' has 5 rows and 50 columns
# Identified new columns: []
# After merging, sheet '4' has 31 rows and 50 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/~$final_merged.xlsx
# Error loading response file '/Users/vineetdixit/Desktop/merge/~$final_merged.xlsx': Excel file format cannot be determined, you must specify an engine manually.
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 1.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 1.xlsx for sheet: 4
# Response sheet '4' has 31 rows and 50 columns
# Identified new columns: []
# After merging, sheet '4' has 31 rows and 50 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/~$Audit Report May24-Sept24.xlsx
# Error loading response file '/Users/vineetdixit/Desktop/merge/~$Audit Report May24-Sept24.xlsx': Excel file format cannot be determined, you must specify an engine manually.
# Processing sheet: 5
# Original sheet '5' loaded with 15 rows and 44 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 3.xlsx
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 2.xlsx
# Checking response file: /Users/vineetdixit/Desktop/merge/final_merged.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/final_merged.xlsx for sheet: 5
# Response sheet '5' has 15 rows and 44 columns
# Identified new columns: []
# After merging, sheet '5' has 15 rows and 44 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 5.xlsx
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 4.xlsx
# Checking response file: /Users/vineetdixit/Desktop/merge/~$final_merged.xlsx
# Error loading response file '/Users/vineetdixit/Desktop/merge/~$final_merged.xlsx': Excel file format cannot be determined, you must specify an engine manually.
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 1.xlsx
# Checking response file: /Users/vineetdixit/Desktop/merge/~$Audit Report May24-Sept24.xlsx
# Error loading response file '/Users/vineetdixit/Desktop/merge/~$Audit Report May24-Sept24.xlsx': Excel file format cannot be determined, you must specify an engine manually.
# Processing sheet: 6
# Original sheet '6' loaded with 65 rows and 42 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 3.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 3.xlsx for sheet: 6
# Response sheet '6' has 65 rows and 45 columns
# Identified new columns: ['Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44']
# After merging, sheet '6' has 65 rows and 45 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 2.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 2.xlsx for sheet: 6
# Response sheet '6' has 65 rows and 45 columns
# Identified new columns: []
# After merging, sheet '6' has 65 rows and 45 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/final_merged.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/final_merged.xlsx for sheet: 6
# Response sheet '6' has 65 rows and 45 columns
# Identified new columns: []
# After merging, sheet '6' has 65 rows and 45 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 5.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 5.xlsx for sheet: 6
# Response sheet '6' has 65 rows and 45 columns
# Identified new columns: []
# After merging, sheet '6' has 65 rows and 45 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 4.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 4.xlsx for sheet: 6
# Response sheet '6' has 17 rows and 45 columns
# Identified new columns: []
# After merging, sheet '6' has 65 rows and 45 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/~$final_merged.xlsx
# Error loading response file '/Users/vineetdixit/Desktop/merge/~$final_merged.xlsx': Excel file format cannot be determined, you must specify an engine manually.
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 1.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 1.xlsx for sheet: 6
# Response sheet '6' has 65 rows and 45 columns
# Identified new columns: []
# After merging, sheet '6' has 65 rows and 45 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/~$Audit Report May24-Sept24.xlsx
# Error loading response file '/Users/vineetdixit/Desktop/merge/~$Audit Report May24-Sept24.xlsx': Excel file format cannot be determined, you must specify an engine manually.
# Processing sheet: 7
# Original sheet '7' loaded with 1910 rows and 47 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 3.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 3.xlsx for sheet: 7
# Response sheet '7' has 1910 rows and 47 columns
# Identified new columns: []
# After merging, sheet '7' has 1910 rows and 47 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 2.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 2.xlsx for sheet: 7
# Response sheet '7' has 1910 rows and 47 columns
# Identified new columns: []
# After merging, sheet '7' has 1910 rows and 47 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/final_merged.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/final_merged.xlsx for sheet: 7
# Response sheet '7' has 1910 rows and 47 columns
# Identified new columns: []
# After merging, sheet '7' has 1910 rows and 47 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 5.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 5.xlsx for sheet: 7
# Response sheet '7' has 1910 rows and 47 columns
# Identified new columns: []
# After merging, sheet '7' has 1910 rows and 47 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 4.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 4.xlsx for sheet: 7
# Response sheet '7' has 600 rows and 47 columns
# Identified new columns: []
# After merging, sheet '7' has 1910 rows and 47 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/~$final_merged.xlsx
# Error loading response file '/Users/vineetdixit/Desktop/merge/~$final_merged.xlsx': Excel file format cannot be determined, you must specify an engine manually.
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 1.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 1.xlsx for sheet: 7
# Response sheet '7' has 1910 rows and 47 columns
# Identified new columns: []
# After merging, sheet '7' has 1910 rows and 47 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/~$Audit Report May24-Sept24.xlsx
# Error loading response file '/Users/vineetdixit/Desktop/merge/~$Audit Report May24-Sept24.xlsx': Excel file format cannot be determined, you must specify an engine manually.
# Processing sheet: 8
# Original sheet '8' loaded with 1971 rows and 48 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 3.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 3.xlsx for sheet: 8
# Response sheet '8' has 1971 rows and 47 columns
# Identified new columns: []
# After merging, sheet '8' has 1971 rows and 48 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 2.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 2.xlsx for sheet: 8
# Response sheet '8' has 1971 rows and 47 columns
# Identified new columns: []
# After merging, sheet '8' has 1971 rows and 48 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/final_merged.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/final_merged.xlsx for sheet: 8
# Response sheet '8' has 1971 rows and 48 columns
# Identified new columns: []
# After merging, sheet '8' has 1971 rows and 48 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 5.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 5.xlsx for sheet: 8
# Response sheet '8' has 1971 rows and 47 columns
# Identified new columns: []
# After merging, sheet '8' has 1971 rows and 48 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 4.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 4.xlsx for sheet: 8
# Response sheet '8' has 315 rows and 47 columns
# Identified new columns: []
# After merging, sheet '8' has 1971 rows and 48 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/~$final_merged.xlsx
# Error loading response file '/Users/vineetdixit/Desktop/merge/~$final_merged.xlsx': Excel file format cannot be determined, you must specify an engine manually.
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 1.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 1.xlsx for sheet: 8
# Response sheet '8' has 1971 rows and 47 columns
# Identified new columns: []
# After merging, sheet '8' has 1971 rows and 48 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/~$Audit Report May24-Sept24.xlsx
# Error loading response file '/Users/vineetdixit/Desktop/merge/~$Audit Report May24-Sept24.xlsx': Excel file format cannot be determined, you must specify an engine manually.
# Processing sheet: 9
# Original sheet '9' loaded with 6 rows and 47 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 3.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 3.xlsx for sheet: 9
# Response sheet '9' has 6 rows and 50 columns
# Identified new columns: ['Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49']
# After merging, sheet '9' has 6 rows and 50 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 2.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 2.xlsx for sheet: 9
# Response sheet '9' has 6 rows and 50 columns
# Identified new columns: []
# After merging, sheet '9' has 6 rows and 50 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/final_merged.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/final_merged.xlsx for sheet: 9
# Response sheet '9' has 6 rows and 50 columns
# Identified new columns: []
# After merging, sheet '9' has 6 rows and 50 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 5.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 5.xlsx for sheet: 9
# Response sheet '9' has 6 rows and 50 columns
# Identified new columns: []
# After merging, sheet '9' has 6 rows and 50 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 4.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 4.xlsx for sheet: 9
# Response sheet '9' has 3 rows and 50 columns
# Identified new columns: []
# After merging, sheet '9' has 6 rows and 50 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/~$final_merged.xlsx
# Error loading response file '/Users/vineetdixit/Desktop/merge/~$final_merged.xlsx': Excel file format cannot be determined, you must specify an engine manually.
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 1.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 1.xlsx for sheet: 9
# Response sheet '9' has 6 rows and 50 columns
# Identified new columns: []
# After merging, sheet '9' has 6 rows and 50 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/~$Audit Report May24-Sept24.xlsx
# Error loading response file '/Users/vineetdixit/Desktop/merge/~$Audit Report May24-Sept24.xlsx': Excel file format cannot be determined, you must specify an engine manually.
# Processing sheet: 10
# Original sheet '10' loaded with 25 rows and 43 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 3.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 3.xlsx for sheet: 10
# Response sheet '10' has 25 rows and 46 columns
# Identified new columns: ['Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45']
# After merging, sheet '10' has 25 rows and 46 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 2.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 2.xlsx for sheet: 10
# Response sheet '10' has 25 rows and 46 columns
# Identified new columns: []
# After merging, sheet '10' has 25 rows and 46 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/final_merged.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/final_merged.xlsx for sheet: 10
# Response sheet '10' has 25 rows and 46 columns
# Identified new columns: []
# After merging, sheet '10' has 25 rows and 46 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 5.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 5.xlsx for sheet: 10
# Response sheet '10' has 25 rows and 46 columns
# Identified new columns: []
# After merging, sheet '10' has 25 rows and 46 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 4.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 4.xlsx for sheet: 10
# Response sheet '10' has 8 rows and 46 columns
# Identified new columns: []
# After merging, sheet '10' has 25 rows and 46 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/~$final_merged.xlsx
# Error loading response file '/Users/vineetdixit/Desktop/merge/~$final_merged.xlsx': Excel file format cannot be determined, you must specify an engine manually.
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 1.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 1.xlsx for sheet: 10
# Response sheet '10' has 25 rows and 46 columns
# Identified new columns: []
# After merging, sheet '10' has 25 rows and 46 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/~$Audit Report May24-Sept24.xlsx
# Error loading response file '/Users/vineetdixit/Desktop/merge/~$Audit Report May24-Sept24.xlsx': Excel file format cannot be determined, you must specify an engine manually.
# Processing sheet: 11
# Original sheet '11' loaded with 164 rows and 45 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 3.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 3.xlsx for sheet: 11
# Response sheet '11' has 164 rows and 48 columns
# Identified new columns: ['Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47']
# After merging, sheet '11' has 164 rows and 48 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 2.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 2.xlsx for sheet: 11
# Response sheet '11' has 164 rows and 48 columns
# Identified new columns: []
# After merging, sheet '11' has 164 rows and 48 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/final_merged.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/final_merged.xlsx for sheet: 11
# Response sheet '11' has 164 rows and 48 columns
# Identified new columns: []
# After merging, sheet '11' has 164 rows and 48 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 5.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 5.xlsx for sheet: 11
# Response sheet '11' has 164 rows and 48 columns
# Identified new columns: []
# After merging, sheet '11' has 164 rows and 48 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 4.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 4.xlsx for sheet: 11
# Response sheet '11' has 38 rows and 48 columns
# Identified new columns: []
# After merging, sheet '11' has 164 rows and 48 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/~$final_merged.xlsx
# Error loading response file '/Users/vineetdixit/Desktop/merge/~$final_merged.xlsx': Excel file format cannot be determined, you must specify an engine manually.
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 1.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 1.xlsx for sheet: 11
# Response sheet '11' has 164 rows and 48 columns
# Identified new columns: []
# After merging, sheet '11' has 164 rows and 48 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/~$Audit Report May24-Sept24.xlsx
# Error loading response file '/Users/vineetdixit/Desktop/merge/~$Audit Report May24-Sept24.xlsx': Excel file format cannot be determined, you must specify an engine manually.
# Processing sheet: 12
# Original sheet '12' loaded with 117 rows and 46 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 3.xlsx
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 2.xlsx
# Checking response file: /Users/vineetdixit/Desktop/merge/final_merged.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/final_merged.xlsx for sheet: 12
# Response sheet '12' has 117 rows and 46 columns
# Identified new columns: []
# After merging, sheet '12' has 117 rows and 46 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 5.xlsx
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 4.xlsx
# Checking response file: /Users/vineetdixit/Desktop/merge/~$final_merged.xlsx
# Error loading response file '/Users/vineetdixit/Desktop/merge/~$final_merged.xlsx': Excel file format cannot be determined, you must specify an engine manually.
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 1.xlsx
# Checking response file: /Users/vineetdixit/Desktop/merge/~$Audit Report May24-Sept24.xlsx
# Error loading response file '/Users/vineetdixit/Desktop/merge/~$Audit Report May24-Sept24.xlsx': Excel file format cannot be determined, you must specify an engine manually.
# Processing sheet: 13
# Original sheet '13' loaded with 138 rows and 49 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 3.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 3.xlsx for sheet: 13
# Response sheet '13' has 138 rows and 52 columns
# Identified new columns: ['Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51']
# After merging, sheet '13' has 138 rows and 52 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 2.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 2.xlsx for sheet: 13
# Response sheet '13' has 138 rows and 52 columns
# Identified new columns: []
# After merging, sheet '13' has 138 rows and 52 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/final_merged.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/final_merged.xlsx for sheet: 13
# Response sheet '13' has 138 rows and 52 columns
# Identified new columns: []
# After merging, sheet '13' has 138 rows and 52 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 5.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 5.xlsx for sheet: 13
# Response sheet '13' has 138 rows and 52 columns
# Identified new columns: []
# After merging, sheet '13' has 138 rows and 52 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 4.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 4.xlsx for sheet: 13
# Response sheet '13' has 2 rows and 52 columns
# Identified new columns: []
# After merging, sheet '13' has 138 rows and 52 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/~$final_merged.xlsx
# Error loading response file '/Users/vineetdixit/Desktop/merge/~$final_merged.xlsx': Excel file format cannot be determined, you must specify an engine manually.
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 1.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 1.xlsx for sheet: 13
# Response sheet '13' has 138 rows and 52 columns
# Identified new columns: []
# After merging, sheet '13' has 138 rows and 52 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/~$Audit Report May24-Sept24.xlsx
# Error loading response file '/Users/vineetdixit/Desktop/merge/~$Audit Report May24-Sept24.xlsx': Excel file format cannot be determined, you must specify an engine manually.
# Processing sheet: A
# Original sheet 'A' loaded with 860 rows and 47 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 3.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 3.xlsx for sheet: A
# Response sheet 'A' has 860 rows and 50 columns
# Identified new columns: ['Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49']
# After merging, sheet 'A' has 860 rows and 50 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 2.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 2.xlsx for sheet: A
# Response sheet 'A' has 860 rows and 50 columns
# Identified new columns: []
# After merging, sheet 'A' has 860 rows and 50 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/final_merged.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/final_merged.xlsx for sheet: A
# Response sheet 'A' has 860 rows and 52 columns
# Identified new columns: ['Unnamed: 50', 'Unnamed: 51']
# After merging, sheet 'A' has 860 rows and 52 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 5.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 5.xlsx for sheet: A
# Response sheet 'A' has 860 rows and 50 columns
# Identified new columns: []
# After merging, sheet 'A' has 860 rows and 52 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 4.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 4.xlsx for sheet: A
# Response sheet 'A' has 122 rows and 52 columns
# Identified new columns: []
# After merging, sheet 'A' has 860 rows and 52 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/~$final_merged.xlsx
# Error loading response file '/Users/vineetdixit/Desktop/merge/~$final_merged.xlsx': Excel file format cannot be determined, you must specify an engine manually.
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 1.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 1.xlsx for sheet: A
# Response sheet 'A' has 860 rows and 50 columns
# Identified new columns: []
# After merging, sheet 'A' has 860 rows and 52 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/~$Audit Report May24-Sept24.xlsx
# Error loading response file '/Users/vineetdixit/Desktop/merge/~$Audit Report May24-Sept24.xlsx': Excel file format cannot be determined, you must specify an engine manually.
# Processing sheet: B
# Original sheet 'B' loaded with 23 rows and 4 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 3.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 3.xlsx for sheet: B
# Response sheet 'B' has 23 rows and 7 columns
# Identified new columns: ['Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6']
# After merging, sheet 'B' has 23 rows and 7 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 2.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 2.xlsx for sheet: B
# Response sheet 'B' has 23 rows and 7 columns
# Identified new columns: []
# After merging, sheet 'B' has 23 rows and 7 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/final_merged.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/final_merged.xlsx for sheet: B
# Response sheet 'B' has 23 rows and 7 columns
# Identified new columns: []
# After merging, sheet 'B' has 23 rows and 7 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 5.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 5.xlsx for sheet: B
# Response sheet 'B' has 23 rows and 7 columns
# Identified new columns: []
# After merging, sheet 'B' has 23 rows and 7 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 4.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 4.xlsx for sheet: B
# Response sheet 'B' has 6 rows and 7 columns
# Identified new columns: []
# After merging, sheet 'B' has 23 rows and 7 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/~$final_merged.xlsx
# Error loading response file '/Users/vineetdixit/Desktop/merge/~$final_merged.xlsx': Excel file format cannot be determined, you must specify an engine manually.
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 1.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 1.xlsx for sheet: B
# Response sheet 'B' has 23 rows and 7 columns
# Identified new columns: []
# After merging, sheet 'B' has 23 rows and 7 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/~$Audit Report May24-Sept24.xlsx
# Error loading response file '/Users/vineetdixit/Desktop/merge/~$Audit Report May24-Sept24.xlsx': Excel file format cannot be determined, you must specify an engine manually.
# Processing sheet: C
# Original sheet 'C' loaded with 8 rows and 47 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 3.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 3.xlsx for sheet: C
# Response sheet 'C' has 8 rows and 50 columns
# Identified new columns: ['Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49']
# After merging, sheet 'C' has 8 rows and 50 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 2.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 2.xlsx for sheet: C
# Response sheet 'C' has 8 rows and 50 columns
# Identified new columns: []
# After merging, sheet 'C' has 8 rows and 50 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/final_merged.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/final_merged.xlsx for sheet: C
# Response sheet 'C' has 8 rows and 50 columns
# Identified new columns: []
# After merging, sheet 'C' has 8 rows and 50 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 5.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 5.xlsx for sheet: C
# Response sheet 'C' has 8 rows and 50 columns
# Identified new columns: []
# After merging, sheet 'C' has 8 rows and 50 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 4.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 4.xlsx for sheet: C
# Response sheet 'C' has 2 rows and 50 columns
# Identified new columns: []
# After merging, sheet 'C' has 8 rows and 50 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/~$final_merged.xlsx
# Error loading response file '/Users/vineetdixit/Desktop/merge/~$final_merged.xlsx': Excel file format cannot be determined, you must specify an engine manually.
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 1.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 1.xlsx for sheet: C
# Response sheet 'C' has 8 rows and 50 columns
# Identified new columns: []
# After merging, sheet 'C' has 8 rows and 50 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/~$Audit Report May24-Sept24.xlsx
# Error loading response file '/Users/vineetdixit/Desktop/merge/~$Audit Report May24-Sept24.xlsx': Excel file format cannot be determined, you must specify an engine manually.
# Processing sheet: D
# Original sheet 'D' loaded with 8 rows and 47 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 3.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 3.xlsx for sheet: D
# Response sheet 'D' has 8 rows and 49 columns
# Identified new columns: ['Unnamed: 47', 'Unnamed: 48']
# After merging, sheet 'D' has 8 rows and 49 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 2.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 2.xlsx for sheet: D
# Response sheet 'D' has 8 rows and 49 columns
# Identified new columns: []
# After merging, sheet 'D' has 8 rows and 49 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/final_merged.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/final_merged.xlsx for sheet: D
# Response sheet 'D' has 8 rows and 49 columns
# Identified new columns: []
# After merging, sheet 'D' has 8 rows and 49 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 5.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 5.xlsx for sheet: D
# Response sheet 'D' has 8 rows and 49 columns
# Identified new columns: []
# After merging, sheet 'D' has 8 rows and 49 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 4.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 4.xlsx for sheet: D
# Response sheet 'D' has 2 rows and 49 columns
# Identified new columns: []
# After merging, sheet 'D' has 8 rows and 49 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/~$final_merged.xlsx
# Error loading response file '/Users/vineetdixit/Desktop/merge/~$final_merged.xlsx': Excel file format cannot be determined, you must specify an engine manually.
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 1.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 1.xlsx for sheet: D
# Response sheet 'D' has 8 rows and 49 columns
# Identified new columns: []
# After merging, sheet 'D' has 8 rows and 49 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/~$Audit Report May24-Sept24.xlsx
# Error loading response file '/Users/vineetdixit/Desktop/merge/~$Audit Report May24-Sept24.xlsx': Excel file format cannot be determined, you must specify an engine manually.
# Processing sheet: E
# Original sheet 'E' loaded with 33776 rows and 2 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 3.xlsx
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 2.xlsx
# Checking response file: /Users/vineetdixit/Desktop/merge/final_merged.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/final_merged.xlsx for sheet: E
# Response sheet 'E' has 33776 rows and 2 columns
# Identified new columns: []
# After merging, sheet 'E' has 33776 rows and 2 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 5.xlsx
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 4.xlsx
# Checking response file: /Users/vineetdixit/Desktop/merge/~$final_merged.xlsx
# Error loading response file '/Users/vineetdixit/Desktop/merge/~$final_merged.xlsx': Excel file format cannot be determined, you must specify an engine manually.
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 1.xlsx
# Checking response file: /Users/vineetdixit/Desktop/merge/~$Audit Report May24-Sept24.xlsx
# Error loading response file '/Users/vineetdixit/Desktop/merge/~$Audit Report May24-Sept24.xlsx': Excel file format cannot be determined, you must specify an engine manually.
# Processing sheet: F
# Original sheet 'F' loaded with 164 rows and 48 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 3.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 3.xlsx for sheet: F
# Response sheet 'F' has 164 rows and 51 columns
# Identified new columns: ['Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50']
# After merging, sheet 'F' has 164 rows and 51 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 2.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 2.xlsx for sheet: F
# Response sheet 'F' has 164 rows and 51 columns
# Identified new columns: []
# After merging, sheet 'F' has 164 rows and 51 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/final_merged.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/final_merged.xlsx for sheet: F
# Response sheet 'F' has 164 rows and 51 columns
# Identified new columns: []
# After merging, sheet 'F' has 164 rows and 51 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 5.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 5.xlsx for sheet: F
# Response sheet 'F' has 164 rows and 51 columns
# Identified new columns: []
# After merging, sheet 'F' has 164 rows and 51 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 4.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 4.xlsx for sheet: F
# Response sheet 'F' has 11 rows and 51 columns
# Identified new columns: []
# After merging, sheet 'F' has 164 rows and 51 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/~$final_merged.xlsx
# Error loading response file '/Users/vineetdixit/Desktop/merge/~$final_merged.xlsx': Excel file format cannot be determined, you must specify an engine manually.
# Checking response file: /Users/vineetdixit/Desktop/merge/Final Audit Report 1.xlsx
# Merging data from /Users/vineetdixit/Desktop/merge/Final Audit Report 1.xlsx for sheet: F
# Response sheet 'F' has 164 rows and 51 columns
# Identified new columns: []
# After merging, sheet 'F' has 164 rows and 51 columns
# Checking response file: /Users/vineetdixit/Desktop/merge/~$Audit Report May24-Sept24.xlsx
# Error loading response file '/Users/vineetdixit/Desktop/merge/~$Audit Report May24-Sept24.xlsx': Excel file format cannot be determined, you must specify an engine manually.
# Saving final merged file: /Users/vineetdixit/Desktop/merge/final_merged.xlsx
# Final merged Excel saved as /Users/vineetdixit/Desktop/merge/final_merged.xlsx
